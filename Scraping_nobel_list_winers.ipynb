# %%
# !pip install scrapy
# Out:
# Collecting scrapy
#   Downloading Scrapy-2.12.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Collecting Twisted>=21.7.0 (from scrapy)
#   Downloading twisted-24.11.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: cryptography>=37.0.0 in /usr/local/lib/python3.11/dist-packages (from scrapy) (43.0.3)
# Collecting cssselect>=0.9.1 (from scrapy)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting itemloaders>=1.0.1 (from scrapy)
#   Downloading itemloaders-1.3.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting parsel>=1.5.0 (from scrapy)
#   Downloading parsel-1.10.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyOpenSSL>=22.0.0 in /usr/local/lib/python3.11/dist-packages (from scrapy) (24.2.1)
# Collecting queuelib>=1.4.2 (from scrapy)
#   Downloading queuelib-1.7.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting service-identity>=18.1.0 (from scrapy)
#   Downloading service_identity-24.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting w3lib>=1.17.0 (from scrapy)
#   Downloading w3lib-2.3.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting zope.interface>=5.1.0 (from scrapy)
#   Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.7 MB/s eta 0:00:00
# Collecting protego>=0.1.15 (from scrapy)
#   Downloading Protego-0.4.0-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting itemadapter>=0.1.0 (from scrapy)
#   Downloading itemadapter-0.11.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from scrapy) (24.2)
# Collecting tldextract (from scrapy)
#   Downloading tldextract-5.1.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: lxml>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from scrapy) (5.3.0)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from scrapy) (0.7.1)
# Collecting PyDispatcher>=2.0.5 (from scrapy)
#   Downloading PyDispatcher-2.0.7-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=37.0.0->scrapy) (1.17.1)
# Collecting jmespath>=0.9.5 (from itemloaders>=1.0.1->scrapy)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.11/dist-packages (from service-identity>=18.1.0->scrapy) (25.1.0)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.11/dist-packages (from service-identity>=18.1.0->scrapy) (0.6.1)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.11/dist-packages (from service-identity>=18.1.0->scrapy) (0.4.1)
# Collecting automat>=24.8.0 (from Twisted>=21.7.0->scrapy)
#   Downloading Automat-24.8.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting constantly>=15.1 (from Twisted>=21.7.0->scrapy)
#   Downloading constantly-23.10.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting hyperlink>=17.1.1 (from Twisted>=21.7.0->scrapy)
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting incremental>=24.7.0 (from Twisted>=21.7.0->scrapy)
#   Downloading incremental-24.7.2-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from Twisted>=21.7.0->scrapy) (4.12.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from zope.interface>=5.1.0->scrapy) (75.1.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from tldextract->scrapy) (3.10)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from tldextract->scrapy) (2.32.3)
# Collecting requests-file>=1.4 (from tldextract->scrapy)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.11/dist-packages (from tldextract->scrapy) (3.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=37.0.0->scrapy) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.1.0->tldextract->scrapy) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2024.12.14)
# Downloading Scrapy-2.12.0-py2.py3-none-any.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 17.2 MB/s eta 0:00:00
# Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Downloading itemadapter-0.11.0-py3-none-any.whl (11 kB)
# Downloading itemloaders-1.3.2-py3-none-any.whl (12 kB)
# Downloading parsel-1.10.0-py2.py3-none-any.whl (17 kB)
# Downloading Protego-0.4.0-py2.py3-none-any.whl (8.6 kB)
# Downloading PyDispatcher-2.0.7-py3-none-any.whl (12 kB)
# Downloading queuelib-1.7.0-py2.py3-none-any.whl (13 kB)
# Downloading service_identity-24.2.0-py3-none-any.whl (11 kB)
# Downloading twisted-24.11.0-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 34.9 MB/s eta 0:00:00
# Downloading w3lib-2.3.1-py3-none-any.whl (21 kB)
# Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 9.6 MB/s eta 0:00:00
# Downloading tldextract-5.1.3-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 3.8 MB/s eta 0:00:00
# Downloading Automat-24.8.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 1.8 MB/s eta 0:00:00
# Downloading constantly-23.10.4-py3-none-any.whl (13 kB)
# Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 5.6 MB/s eta 0:00:00
# Downloading incremental-24.7.2-py3-none-any.whl (20 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Installing collected packages: PyDispatcher, zope.interface, w3lib, queuelib, protego, jmespath, itemadapter, incremental, hyperlink, cssselect, constantly, automat, Twisted, requests-file, parsel, tldextract, service-identity, itemloaders, scrapy
# Successfully installed PyDispatcher-2.0.7 Twisted-24.11.0 automat-24.8.1 constantly-23.10.4 cssselect-1.2.0 hyperlink-21.0.0 incremental-24.7.2 itemadapter-0.11.0 itemloaders-1.3.2 jmespath-1.0.1 parsel-1.10.0 protego-0.4.0 queuelib-1.7.0 requests-file-2.1.0 scrapy-2.12.0 service-identity-24.2.0 tldextract-5.1.3 w3lib-2.3.1 zope.interface-7.2

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

# Define the data model for storing Nobel Prize winners' information
class NWinnerItem(scrapy.Item):
    country = scrapy.Field()  # Country name
    name = scrapy.Field()  # Nobel laureate's name
    link_text = scrapy.Field()  # Full text from the list item

# Define the Scrapy Spider to scrape data from Wikipedia
class NWinnerSpider(scrapy.Spider):
    name = 'nwinners_list'  # Unique name for the spider
    allowed_domains = ['en.wikipedia.org']  # Allowed domain to scrape
    start_urls = [
        "https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country"
    ]  # List of URLs to start crawling from

    def parse(self, response):
        h3s = response.xpath('//h3')  # Find all <h3> headers (country names)

        for h3 in h3s:
            country = h3.xpath('./text()').get()  # Extract the country name
            if country:
                # Find the ordered list <ol> that comes immediately after the <h3>
                winners = h3.xpath('../following-sibling::ol[1]/li')
                for w in winners:
                    text = w.xpath('.//text()').getall()  # Extract all text from the list item
                    yield NWinnerItem(
                        country=country.strip(),  # Clean country name
                        name=text[0].strip(),  # Get the first text element (winner's name)
                        link_text=' '.join(text).strip()  # Join all text elements into a single string
                    )
# Use CrawlerProcess to run Scrapy within a script (useful for Google Colab)
process = CrawlerProcess(settings={
    "FEEDS": {  # Define the output file and format
        "nobel_winners.json": {"format": "json"},
    },
})

process.crawl(NWinnerSpider)  # Start the spider
process.start()  # Run the Scrapy process
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Heinrich Rohrer , Physics, 1986',
#  'name': 'Heinrich Rohrer'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Heinrich Rohrer , Physics, 1986',
#  'name': 'Heinrich Rohrer'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Werner Arber , Physiology or Medicine, 1978',
#  'name': 'Werner Arber'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Werner Arber , Physiology or Medicine, 1978',
#  'name': 'Werner Arber'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Daniel Bovet , Physiology or Medicine, 1957',
#  'name': 'Daniel Bovet'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Daniel Bovet , Physiology or Medicine, 1957',
#  'name': 'Daniel Bovet'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Felix Bloch , Physics, 1952',
#  'name': 'Felix Bloch'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Felix Bloch , Physics, 1952',
#  'name': 'Felix Bloch'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Tadeusz Reichstein , Physiology or Medicine, 1950',
#  'name': 'Tadeusz Reichstein'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Tadeusz Reichstein , Physiology or Medicine, 1950',
#  'name': 'Tadeusz Reichstein'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Walter Rudolf Hess , Physiology or Medicine, 1949',
#  'name': 'Walter Rudolf Hess'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Walter Rudolf Hess , Physiology or Medicine, 1949',
#  'name': 'Walter Rudolf Hess'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Paul Hermann Müller , Physiology or Medicine, 1948',
#  'name': 'Paul Hermann Müller'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Paul Hermann Müller , Physiology or Medicine, 1948',
#  'name': 'Paul Hermann Müller'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Hermann Hesse ,  born in Germany , Literature, 1946',
#  'name': 'Hermann Hesse'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Hermann Hesse ,  born in Germany , Literature, 1946',
#  'name': 'Hermann Hesse'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Paul Karrer , Chemistry, 1937',
#  'name': 'Paul Karrer'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Paul Karrer , Chemistry, 1937',
#  'name': 'Paul Karrer'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Albert Einstein ,  born in Germany , Physics, 1921',
#  'name': 'Albert Einstein'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Albert Einstein ,  born in Germany , Physics, 1921',
#  'name': 'Albert Einstein'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Charles Édouard Guillaume , Physics, 1920',
#  'name': 'Charles Édouard Guillaume'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Charles Édouard Guillaume , Physics, 1920',
#  'name': 'Charles Édouard Guillaume'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Carl Spitteler , Literature, 1919',
#  'name': 'Carl Spitteler'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Carl Spitteler , Literature, 1919',
#  'name': 'Carl Spitteler'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Alfred Werner , Chemistry, 1913',
#  'name': 'Alfred Werner'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Alfred Werner , Chemistry, 1913',
#  'name': 'Alfred Werner'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Theodor Kocher , Physiology or Medicine, 1909',
#  'name': 'Theodor Kocher'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Theodor Kocher , Physiology or Medicine, 1909',
#  'name': 'Theodor Kocher'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Élie Ducommun , Peace, 1902',
#  'name': 'Élie Ducommun'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Élie Ducommun , Peace, 1902',
#  'name': 'Élie Ducommun'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Charles Albert Gobat , Peace, 1902',
#  'name': 'Charles Albert Gobat'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Charles Albert Gobat , Peace, 1902',
#  'name': 'Charles Albert Gobat'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Henry Dunant , Peace, 1901',
#  'name': 'Henry Dunant'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Henry Dunant , Peace, 1901',
#  'name': 'Henry Dunant'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Vladimir Prelog *,   Resided in what is now  Croatia , born in  '
#               'Condominium of Bosnia and Herzegovina ,  Austro-Hungarian '
#               'Empire  (now  Bosnia and Herzegovina ) , Chemistry, 1975',
#  'name': 'Vladimir Prelog'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Vladimir Prelog *,   Resided in what is now  Croatia , born in  '
#               'Condominium of Bosnia and Herzegovina ,  Austro-Hungarian '
#               'Empire  (now  Bosnia and Herzegovina ) , Chemistry, 1975',
#  'name': 'Vladimir Prelog'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Leopold Ružička *,  Resided in what is now  Croatia , born in '
#               'the  Kingdom of Croatia-Slavonia  part of  Kingdom of Hungary  '
#               'in  Austro-Hungarian Empire  (now  Croatia ) , Chemistry, 1939',
#  'name': 'Leopold Ružička'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Switzerland',
#  'link_text': 'Leopold Ružička *,  Resided in what is now  Croatia , born in '
#               'the  Kingdom of Croatia-Slavonia  part of  Kingdom of Hungary  '
#               'in  Austro-Hungarian Empire  (now  Croatia ) , Chemistry, 1939',
#  'name': 'Leopold Ružička'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Tanzania',
#  'link_text': 'Abdulrazak Gurnah *, Literature, 2021',
#  'name': 'Abdulrazak Gurnah'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Tanzania',
#  'link_text': 'Abdulrazak Gurnah *, Literature, 2021',
#  'name': 'Abdulrazak Gurnah'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Trinidad and Tobago',
#  'link_text': 'V. S. Naipaul *, Literature, 2001',
#  'name': 'V. S. Naipaul'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Trinidad and Tobago',
#  'link_text': 'V. S. Naipaul *, Literature, 2001',
#  'name': 'V. S. Naipaul'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Tunisia',
#  'link_text': 'Moungi Bawendi **,  born in France , Chemistry, 2023',
#  'name': 'Moungi Bawendi'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Tunisia',
#  'link_text': 'Moungi Bawendi **,  born in France , Chemistry, 2023',
#  'name': 'Moungi Bawendi'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Tunisia',
#  'link_text': 'Pierre Agostini *, Physics, 2023',
#  'name': 'Pierre Agostini'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Tunisia',
#  'link_text': 'Pierre Agostini *, Physics, 2023',
#  'name': 'Pierre Agostini'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Tunisia',
#  'link_text': 'Tunisian National Dialogue Quartet , Peace, 2015',
#  'name': 'Tunisian National Dialogue Quartet'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Tunisia',
#  'link_text': 'Tunisian National Dialogue Quartet , Peace, 2015',
#  'name': 'Tunisian National Dialogue Quartet'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Turkey',
#  'link_text': 'Daron Acemoglu *, Economics, 2024',
#  'name': 'Daron Acemoglu'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Turkey',
#  'link_text': 'Daron Acemoglu *, Economics, 2024',
#  'name': 'Daron Acemoglu'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Turkey',
#  'link_text': 'Aziz Sancar* , Chemistry, 2015',
#  'name': 'Aziz Sancar*'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Turkey',
#  'link_text': 'Aziz Sancar* , Chemistry, 2015',
#  'name': 'Aziz Sancar*'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Turkey',
#  'link_text': 'Orhan Pamuk , Literature, 2006',
#  'name': 'Orhan Pamuk'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Turkey',
#  'link_text': 'Orhan Pamuk , Literature, 2006',
#  'name': 'Orhan Pamuk'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Turkey',
#  'link_text': 'Giorgos Seferis *,  born in Ottoman Empire, now Turkey , '
#               'Literature, 1963',
#  'name': 'Giorgos Seferis'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Turkey',
#  'link_text': 'Giorgos Seferis *,  born in Ottoman Empire, now Turkey , '
#               'Literature, 1963',
#  'name': 'Giorgos Seferis'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Ukraine',
#  'link_text': 'Centre for Civil Liberties , Peace, 2022',
#  'name': 'Centre for Civil Liberties'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Ukraine',
#  'link_text': 'Centre for Civil Liberties , Peace, 2022',
#  'name': 'Centre for Civil Liberties'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Ukraine',
#  'link_text': 'Svetlana Alexievich *,  born in Ukraine , Literature, 2015',
#  'name': 'Svetlana Alexievich'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Ukraine',
#  'link_text': 'Svetlana Alexievich *,  born in Ukraine , Literature, 2015',
#  'name': 'Svetlana Alexievich'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Ukraine',
#  'link_text': 'Georges Charpak *,  born in Ukraine, then a part of Poland,  '
#               'Physics, 1992',
#  'name': 'Georges Charpak'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Ukraine',
#  'link_text': 'Georges Charpak *,  born in Ukraine, then a part of Poland,  '
#               'Physics, 1992',
#  'name': 'Georges Charpak'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Ukraine',
#  'link_text': 'Roald Hoffmann *,  born in Ukraine, then a part of Poland,  '
#               'Chemistry, 1981',
#  'name': 'Roald Hoffmann'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Ukraine',
#  'link_text': 'Roald Hoffmann *,  born in Ukraine, then a part of Poland,  '
#               'Chemistry, 1981',
#  'name': 'Roald Hoffmann'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Ukraine',
#  'link_text': 'Shmuel Yosef Agnon *,  born in Ukraine, then a part of Poland,  '
#               'Literature, 1966',
#  'name': 'Shmuel Yosef Agnon'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Ukraine',
#  'link_text': 'Shmuel Yosef Agnon *,  born in Ukraine, then a part of Poland,  '
#               'Literature, 1966',
#  'name': 'Shmuel Yosef Agnon'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Ukraine',
#  'link_text': 'Selman Waksman *,  born in Ukraine , Physiology or Medicine, '
#               '1952',
#  'name': 'Selman Waksman'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Ukraine',
#  'link_text': 'Selman Waksman *,  born in Ukraine , Physiology or Medicine, '
#               '1952',
#  'name': 'Selman Waksman'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Ukraine',
#  'link_text': 'Ilya Ilyich Mechnikov ,  born in Ukraine, then a part of '
#               'Russia,  Physiology or Medicine, 1908',
#  'name': 'Ilya Ilyich Mechnikov'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Ukraine',
#  'link_text': 'Ilya Ilyich Mechnikov ,  born in Ukraine, then a part of '
#               'Russia,  Physiology or Medicine, 1908',
#  'name': 'Ilya Ilyich Mechnikov'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'James A. Robinson , Economics, 2024',
#  'name': 'James A. Robinson'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'James A. Robinson , Economics, 2024',
#  'name': 'James A. Robinson'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Simon Johnson , Economics, 2024',
#  'name': 'Simon Johnson'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Simon Johnson , Economics, 2024',
#  'name': 'Simon Johnson'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Geoffrey Hinton , Physics, 2024',
#  'name': 'Geoffrey Hinton'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Geoffrey Hinton , Physics, 2024',
#  'name': 'Geoffrey Hinton'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Demis Hassabis , Chemistry, 2024',
#  'name': 'Demis Hassabis'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Demis Hassabis , Chemistry, 2024',
#  'name': 'Demis Hassabis'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Abdulrazak Gurnah ,  born in Tanzania , Literature, 2021',
#  'name': 'Abdulrazak Gurnah'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Abdulrazak Gurnah ,  born in Tanzania , Literature, 2021',
#  'name': 'Abdulrazak Gurnah'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'David MacMillan , Chemistry, 2021',
#  'name': 'David MacMillan'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'David MacMillan , Chemistry, 2021',
#  'name': 'David MacMillan'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Roger Penrose , Physics, 2020',
#  'name': 'Roger Penrose'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Roger Penrose , Physics, 2020',
#  'name': 'Roger Penrose'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Michael Houghton , Physiology or Medicine, 2020',
#  'name': 'Michael Houghton'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Michael Houghton , Physiology or Medicine, 2020',
#  'name': 'Michael Houghton'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Peter J. Ratcliffe , Physiology or Medicine, 2019',
#  'name': 'Peter J. Ratcliffe'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Peter J. Ratcliffe , Physiology or Medicine, 2019',
#  'name': 'Peter J. Ratcliffe'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'M. Stanley Whittingham , Chemistry, 2019',
#  'name': 'M. Stanley Whittingham'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'M. Stanley Whittingham , Chemistry, 2019',
#  'name': 'M. Stanley Whittingham'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Greg Winter , Chemistry, 2018',
#  'name': 'Greg Winter'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Greg Winter , Chemistry, 2018',
#  'name': 'Greg Winter'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Kazuo Ishiguro ,  born in Japan , Literature, 2017',
#  'name': 'Kazuo Ishiguro'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Kazuo Ishiguro ,  born in Japan , Literature, 2017',
#  'name': 'Kazuo Ishiguro'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Richard Henderson , Chemistry, 2017',
#  'name': 'Richard Henderson'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Richard Henderson , Chemistry, 2017',
#  'name': 'Richard Henderson'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Oliver Hart , Economics, 2016',
#  'name': 'Oliver Hart'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Oliver Hart , Economics, 2016',
#  'name': 'Oliver Hart'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Fraser Stoddart , Chemistry, 2016',
#  'name': 'Fraser Stoddart'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Fraser Stoddart , Chemistry, 2016',
#  'name': 'Fraser Stoddart'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'David J. Thouless , Physics, 2016',
#  'name': 'David J. Thouless'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'David J. Thouless , Physics, 2016',
#  'name': 'David J. Thouless'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'F. Duncan M. Haldane , Physics, 2016',
#  'name': 'F. Duncan M. Haldane'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'F. Duncan M. Haldane , Physics, 2016',
#  'name': 'F. Duncan M. Haldane'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'John M. Kosterlitz , Physics, 2016',
#  'name': 'John M. Kosterlitz'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'John M. Kosterlitz , Physics, 2016',
#  'name': 'John M. Kosterlitz'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Angus Deaton , Economics, 2015',
#  'name': 'Angus Deaton'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Angus Deaton , Economics, 2015',
#  'name': 'Angus Deaton'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Tomas Lindahl ,  born in Sweden , Chemistry, 2015',
#  'name': 'Tomas Lindahl'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Tomas Lindahl ,  born in Sweden , Chemistry, 2015',
#  'name': 'Tomas Lindahl'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': "John O'Keefe ,  born in the United States , Physiology or "
#               'Medicine, 2014',
#  'name': "John O'Keefe"}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': "John O'Keefe ,  born in the United States , Physiology or "
#               'Medicine, 2014',
#  'name': "John O'Keefe"}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Michael Levitt ,  born in South Africa , Chemistry, 2013',
#  'name': 'Michael Levitt'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Michael Levitt ,  born in South Africa , Chemistry, 2013',
#  'name': 'Michael Levitt'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Peter Higgs , Physics, 2013',
#  'name': 'Peter Higgs'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Peter Higgs , Physics, 2013',
#  'name': 'Peter Higgs'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'John Gurdon , Physiology or Medicine, 2012',
#  'name': 'John Gurdon'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'John Gurdon , Physiology or Medicine, 2012',
#  'name': 'John Gurdon'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Christopher A. Pissarides ,  born in Cyprus , Economics, 2010',
#  'name': 'Christopher A. Pissarides'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Christopher A. Pissarides ,  born in Cyprus , Economics, 2010',
#  'name': 'Christopher A. Pissarides'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Konstantin Novoselov ,  born in Russia , Physics, 2010',
#  'name': 'Konstantin Novoselov'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Konstantin Novoselov ,  born in Russia , Physics, 2010',
#  'name': 'Konstantin Novoselov'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Robert G. Edwards , Physiology or Medicine, 2010',
#  'name': 'Robert G. Edwards'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Robert G. Edwards , Physiology or Medicine, 2010',
#  'name': 'Robert G. Edwards'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Charles K. Kao , Physics, 2009',
#  'name': 'Charles K. Kao'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Charles K. Kao , Physics, 2009',
#  'name': 'Charles K. Kao'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Venkatraman Ramakrishnan ,  born in India , Chemistry, 2009',
#  'name': 'Venkatraman Ramakrishnan'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Venkatraman Ramakrishnan ,  born in India , Chemistry, 2009',
#  'name': 'Venkatraman Ramakrishnan'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Jack W. Szostak ,  born in United Kingdom , Physiology or '
#               'Medicine, 2009',
#  'name': 'Jack W. Szostak'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Jack W. Szostak ,  born in United Kingdom , Physiology or '
#               'Medicine, 2009',
#  'name': 'Jack W. Szostak'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Doris Lessing ,  born in Iran , Literature, 2007',
#  'name': 'Doris Lessing'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Doris Lessing ,  born in Iran , Literature, 2007',
#  'name': 'Doris Lessing'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Sir Martin J. Evans , Physiology or Medicine, 2007',
#  'name': 'Sir Martin J. Evans'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Sir Martin J. Evans , Physiology or Medicine, 2007',
#  'name': 'Sir Martin J. Evans'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Oliver Smithies *, Physiology or Medicine, 2007',
#  'name': 'Oliver Smithies'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Oliver Smithies *, Physiology or Medicine, 2007',
#  'name': 'Oliver Smithies'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Harold Pinter , Literature, 2005',
#  'name': 'Harold Pinter'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Harold Pinter , Literature, 2005',
#  'name': 'Harold Pinter'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Clive W. J. Granger , Economics, 2003',
#  'name': 'Clive W. J. Granger'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Clive W. J. Granger , Economics, 2003',
#  'name': 'Clive W. J. Granger'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Anthony J. Leggett *, Physics, 2003',
#  'name': 'Anthony J. Leggett'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Anthony J. Leggett *, Physics, 2003',
#  'name': 'Anthony J. Leggett'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Peter Mansfield , Physiology or Medicine, 2003',
#  'name': 'Peter Mansfield'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Peter Mansfield , Physiology or Medicine, 2003',
#  'name': 'Peter Mansfield'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Sydney Brenner ,  born in South Africa , Physiology or '
#               'Medicine, 2002',
#  'name': 'Sydney Brenner'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Sydney Brenner ,  born in South Africa , Physiology or '
#               'Medicine, 2002',
#  'name': 'Sydney Brenner'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'John E. Sulston , Physiology or Medicine, 2002',
#  'name': 'John E. Sulston'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'John E. Sulston , Physiology or Medicine, 2002',
#  'name': 'John E. Sulston'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Tim Hunt , Physiology or Medicine, 2001',
#  'name': 'Tim Hunt'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Tim Hunt , Physiology or Medicine, 2001',
#  'name': 'Tim Hunt'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Paul Nurse , Physiology or Medicine, 2001',
#  'name': 'Paul Nurse'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Paul Nurse , Physiology or Medicine, 2001',
#  'name': 'Paul Nurse'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'V. S. Naipaul ,  born in Trinidad , Literature, 2001',
#  'name': 'V. S. Naipaul'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'V. S. Naipaul ,  born in Trinidad , Literature, 2001',
#  'name': 'V. S. Naipaul'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'David Trimble , Peace, 1998',
#  'name': 'David Trimble'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'David Trimble , Peace, 1998',
#  'name': 'David Trimble'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'John Pople , Chemistry, 1998',
#  'name': 'John Pople'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'John Pople , Chemistry, 1998',
#  'name': 'John Pople'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'John E. Walker , Chemistry, 1997',
#  'name': 'John E. Walker'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'John E. Walker , Chemistry, 1997',
#  'name': 'John E. Walker'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Harold Kroto , Chemistry, 1996',
#  'name': 'Harold Kroto'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Harold Kroto , Chemistry, 1996',
#  'name': 'Harold Kroto'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'James A. Mirrlees , Economics, 1996',
#  'name': 'James A. Mirrlees'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'James A. Mirrlees , Economics, 1996',
#  'name': 'James A. Mirrlees'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Joseph Rotblat ,  born in then Russian Empire, now Poland , '
#               'Peace, 1995',
#  'name': 'Joseph Rotblat'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Joseph Rotblat ,  born in then Russian Empire, now Poland , '
#               'Peace, 1995',
#  'name': 'Joseph Rotblat'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Richard J. Roberts , Physiology or Medicine, 1993',
#  'name': 'Richard J. Roberts'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Richard J. Roberts , Physiology or Medicine, 1993',
#  'name': 'Richard J. Roberts'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Michael Smith *, Chemistry, 1993',
#  'name': 'Michael Smith'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Michael Smith *, Chemistry, 1993',
#  'name': 'Michael Smith'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Ronald Coase ,  based in the United States , Economics, 1991',
#  'name': 'Ronald Coase'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Ronald Coase ,  based in the United States , Economics, 1991',
#  'name': 'Ronald Coase'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'James W. Black , Physiology or Medicine, 1988',
#  'name': 'James W. Black'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'James W. Black , Physiology or Medicine, 1988',
#  'name': 'James W. Black'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'César Milstein ,  born in Argentina , Physiology or Medicine, '
#               '1984',
#  'name': 'César Milstein'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'César Milstein ,  born in Argentina , Physiology or Medicine, '
#               '1984',
#  'name': 'César Milstein'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Richard Stone , Economics, 1984',
#  'name': 'Richard Stone'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Richard Stone , Economics, 1984',
#  'name': 'Richard Stone'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'William Golding , Literature, 1983',
#  'name': 'William Golding'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'William Golding , Literature, 1983',
#  'name': 'William Golding'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Aaron Klug ,  born in Lithuania , Chemistry, 1982',
#  'name': 'Aaron Klug'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Aaron Klug ,  born in Lithuania , Chemistry, 1982',
#  'name': 'Aaron Klug'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'John Robert Vane , Physiology or Medicine, 1982',
#  'name': 'John Robert Vane'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'John Robert Vane , Physiology or Medicine, 1982',
#  'name': 'John Robert Vane'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Elias Canetti ,  born in Bulgaria , Literature, 1981',
#  'name': 'Elias Canetti'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Elias Canetti ,  born in Bulgaria , Literature, 1981',
#  'name': 'Elias Canetti'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Frederick Sanger , Chemistry, 1980',
#  'name': 'Frederick Sanger'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Frederick Sanger , Chemistry, 1980',
#  'name': 'Frederick Sanger'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'W. Arthur Lewis ,  born on St. Lucia , Economics, 1979',
#  'name': 'W. Arthur Lewis'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'W. Arthur Lewis ,  born on St. Lucia , Economics, 1979',
#  'name': 'W. Arthur Lewis'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Godfrey Hounsfield , Physiology or Medicine, 1979',
#  'name': 'Godfrey Hounsfield'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Godfrey Hounsfield , Physiology or Medicine, 1979',
#  'name': 'Godfrey Hounsfield'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Peter D. Mitchell , Chemistry, 1978',
#  'name': 'Peter D. Mitchell'}
# 2025-02-03 01:46:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'Peter D. Mitchell , Chemistry, 1978',
#  'name': 'Peter D. Mitchell'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United Kingdom',
#  'link_text': 'James Meade , Economics, 1977',
#  'name': 'James Meade'}
# ...
#  'link_text': 'Edward A. Doisy , Physiology or Medicine, 1943',
#  'name': 'Edward A. Doisy'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Ernest Lawrence , Physics, 1939',
#  'name': 'Ernest Lawrence'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Ernest Lawrence , Physics, 1939',
#  'name': 'Ernest Lawrence'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Pearl S. Buck , Literature, 1938',
#  'name': 'Pearl S. Buck'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Pearl S. Buck , Literature, 1938',
#  'name': 'Pearl S. Buck'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Clinton Davisson , Physics, 1937',
#  'name': 'Clinton Davisson'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Clinton Davisson , Physics, 1937',
#  'name': 'Clinton Davisson'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': "Eugene O'Neill , Literature, 1936",
#  'name': "Eugene O'Neill"}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': "Eugene O'Neill , Literature, 1936",
#  'name': "Eugene O'Neill"}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Carl Anderson , Physics, 1936',
#  'name': 'Carl Anderson'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Carl Anderson , Physics, 1936',
#  'name': 'Carl Anderson'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Harold C. Urey , Chemistry, 1934',
#  'name': 'Harold C. Urey'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Harold C. Urey , Chemistry, 1934',
#  'name': 'Harold C. Urey'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'George R. Minot , Physiology or Medicine, 1934',
#  'name': 'George R. Minot'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'George R. Minot , Physiology or Medicine, 1934',
#  'name': 'George R. Minot'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'William P. Murphy , Physiology or Medicine, 1934',
#  'name': 'William P. Murphy'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'William P. Murphy , Physiology or Medicine, 1934',
#  'name': 'William P. Murphy'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'George H. Whipple , Physiology or Medicine, 1934',
#  'name': 'George H. Whipple'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'George H. Whipple , Physiology or Medicine, 1934',
#  'name': 'George H. Whipple'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Thomas H. Morgan , Physiology or Medicine, 1933',
#  'name': 'Thomas H. Morgan'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Thomas H. Morgan , Physiology or Medicine, 1933',
#  'name': 'Thomas H. Morgan'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Irving Langmuir , Chemistry, 1932',
#  'name': 'Irving Langmuir'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Irving Langmuir , Chemistry, 1932',
#  'name': 'Irving Langmuir'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Jane Addams , Peace, 1931',
#  'name': 'Jane Addams'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Jane Addams , Peace, 1931',
#  'name': 'Jane Addams'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Nicholas M. Butler , Peace, 1931',
#  'name': 'Nicholas M. Butler'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Nicholas M. Butler , Peace, 1931',
#  'name': 'Nicholas M. Butler'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Sinclair Lewis , Literature, 1930',
#  'name': 'Sinclair Lewis'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Sinclair Lewis , Literature, 1930',
#  'name': 'Sinclair Lewis'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Frank B. Kellogg , Peace, 1929',
#  'name': 'Frank B. Kellogg'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Frank B. Kellogg , Peace, 1929',
#  'name': 'Frank B. Kellogg'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Arthur H. Compton , Physics, 1927',
#  'name': 'Arthur H. Compton'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Arthur H. Compton , Physics, 1927',
#  'name': 'Arthur H. Compton'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Charles G. Dawes , Peace, 1925',
#  'name': 'Charles G. Dawes'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Charles G. Dawes , Peace, 1925',
#  'name': 'Charles G. Dawes'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Robert A. Millikan , Physics, 1923',
#  'name': 'Robert A. Millikan'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Robert A. Millikan , Physics, 1923',
#  'name': 'Robert A. Millikan'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Woodrow Wilson , Peace, 1919',
#  'name': 'Woodrow Wilson'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Woodrow Wilson , Peace, 1919',
#  'name': 'Woodrow Wilson'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Theodore W. Richards , Chemistry, 1914',
#  'name': 'Theodore W. Richards'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Theodore W. Richards , Chemistry, 1914',
#  'name': 'Theodore W. Richards'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Elihu Root , Peace, 1912',
#  'name': 'Elihu Root'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Elihu Root , Peace, 1912',
#  'name': 'Elihu Root'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Albert A. Michelson ,  born in then  Germany , now  Poland , '
#               'Physics, 1907',
#  'name': 'Albert A. Michelson'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Albert A. Michelson ,  born in then  Germany , now  Poland , '
#               'Physics, 1907',
#  'name': 'Albert A. Michelson'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Theodore Roosevelt , Peace, 1906',
#  'name': 'Theodore Roosevelt'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'United States',
#  'link_text': 'Theodore Roosevelt , Peace, 1906',
#  'name': 'Theodore Roosevelt'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Venezuela',
#  'link_text': 'Baruj Benacerraf *, Physiology or Medicine, 1980',
#  'name': 'Baruj Benacerraf'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Venezuela',
#  'link_text': 'Baruj Benacerraf *, Physiology or Medicine, 1980',
#  'name': 'Baruj Benacerraf'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Vietnam',
#  'link_text': 'Lê Đức Thọ ,  born in French Indochina , Peace, 1973 (declined)',
#  'name': 'Lê Đức Thọ'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Vietnam',
#  'link_text': 'Lê Đức Thọ ,  born in French Indochina , Peace, 1973 (declined)',
#  'name': 'Lê Đức Thọ'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Yemen',
#  'link_text': 'Tawakkol Karman , Peace, 2011',
#  'name': 'Tawakkol Karman'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Yemen',
#  'link_text': 'Tawakkol Karman , Peace, 2011',
#  'name': 'Tawakkol Karman'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Yugoslavia',
#  'link_text': 'Ivo Andrić ,  born in the  Condominium of Bosnia and '
#               'Herzegovina ,  Austria-Hungary  (now  Bosnia and Herzegovina ) '
#               ', Literature, 1961',
#  'name': 'Ivo Andrić'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Yugoslavia',
#  'link_text': 'Ivo Andrić ,  born in the  Condominium of Bosnia and '
#               'Herzegovina ,  Austria-Hungary  (now  Bosnia and Herzegovina ) '
#               ', Literature, 1961',
#  'name': 'Ivo Andrić'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Zimbabwe',
#  'link_text': 'Albert Lutuli ,  born in then  Rhodesia , now Zimbabwe , Peace, '
#               '1960',
#  'name': 'Albert Lutuli'}
# 2025-02-03 01:46:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country>
# {'country': 'Zimbabwe',
#  'link_text': 'Albert Lutuli ,  born in then  Rhodesia , now Zimbabwe , Peace, '
#               '1960',
#  'name': 'Albert Lutuli'}
# INFO:scrapy.core.engine:Closing spider (finished)
# 2025-02-03 01:46:35 [scrapy.core.engine] INFO: Closing spider (finished)
# INFO:scrapy.extensions.feedexport:Stored json feed (1242 items) in: nobel_winners.json
# 2025-02-03 01:46:35 [scrapy.extensions.feedexport] INFO: Stored json feed (1242 items) in: nobel_winners.json
# INFO:scrapy.statscollectors:Dumping Scrapy stats:
# {'downloader/request_bytes': 262,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 72622,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 6.87605,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 2, 3, 1, 46, 35, 878977, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 424445,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 1242,
#  'items_per_minute': None,
#  'log_count/DEBUG': 1246,
#  'log_count/INFO': 11,
#  'memusage/max': 159629312,
#  'memusage/startup': 159629312,
#  'response_received_count': 1,
#  'responses_per_minute': None,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2025, 2, 3, 1, 46, 29, 2927, tzinfo=datetime.timezone.utc)}
# 2025-02-03 01:46:35 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 262,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 72622,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 6.87605,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 2, 3, 1, 46, 35, 878977, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 424445,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 1242,
#  'items_per_minute': None,
#  'log_count/DEBUG': 1246,
#  'log_count/INFO': 11,
#  'memusage/max': 159629312,
#  'memusage/startup': 159629312,
#  'response_received_count': 1,
#  'responses_per_minute': None,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2025, 2, 3, 1, 46, 29, 2927, tzinfo=datetime.timezone.utc)}
# INFO:scrapy.core.engine:Spider closed (finished)
# 2025-02-03 01:46:35 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
import json

with open("nobel_winners.json", "r") as file:
    data = json.load(file)

print(json.dumps(data[:5], indent=2))  # Show the first five results
# Out:
# [
#   {
#     "country": "Algeria",
#     "name": "Claude Cohen-Tannoudji",
#     "link_text": "Claude Cohen-Tannoudji *, Physics, 1997"
#   },
#   {
#     "country": "Algeria",
#     "name": "Albert Camus",
#     "link_text": "Albert Camus *, Literature, 1957"
#   },
#   {
#     "country": "Argentina",
#     "name": "C\u00e9sar Milstein",
#     "link_text": "C\u00e9sar Milstein *, Physiology or Medicine, 1984"
#   },
#   {
#     "country": "Argentina",
#     "name": "Adolfo P\u00e9rez Esquivel",
#     "link_text": "Adolfo P\u00e9rez Esquivel , Peace, 1980"
#   },
#   {
#     "country": "Argentina",
#     "name": "Luis Federico Leloir",
#     "link_text": "Luis Federico Leloir ,  born in France , Chemistry, 1970"
#   }
# ]
